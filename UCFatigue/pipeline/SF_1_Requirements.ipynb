# %% [markdown]
# # Surrogate Factory — UCFatigue
# ## Chapter 1. Requirements
# Objectives:
# - Setup general configuration of the pipeline.
# - Define accuracy requirements for the 7 fatigue-load outputs:
#   `1g`, `Vertical maneuver`, `Vertical gust`, `Turn`, `Frontal gust`, `n0`, `Giro`.

# %% [markdown]
# ### 0. Workflow initialisation

# %%
from pathlib import Path
from IPython.display import display, HTML, JSON
from surrogate_factory.workflow import Workflow

workflow = Workflow("pipeline_config.yaml")

# Create output folders — gitignored so they won't exist on a fresh clone
Path(workflow.config['data.folder']).mkdir(parents=True, exist_ok=True)
Path(workflow.config['artifacts.folder']).mkdir(parents=True, exist_ok=True)
# Out:
# 2026-06-25 12:24:15 - SurrogateFactoryLogs - INFO - Initializing Workflow...
# 2026-06-25 12:24:15 - SurrogateFactoryLogs - INFO - Setting up Workflow folders and paths...
# 2026-06-25 12:24:15 - SurrogateFactoryLogs - INFO - Changing working directory to Data folder: /Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/data
# 2026-06-25 12:24:15 - SurrogateFactoryLogs - INFO - Loading default metadata schema...
# 2026-06-25 12:24:15 - SurrogateFactoryLogs - INFO - Tracker requested: 'mlflow'
# 2026-06-25 12:24:15 - SurrogateFactoryLogs - INFO - Setting up MLflow tracking environment...
# Setting tracking uri: file:///Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/mlruns
# 2026-06-25 12:24:15 - SurrogateFactoryLogs - INFO - Adding methods to Catalog from configuration.
# 2026-06-25 12:24:16 - SurrogateFactoryLogs - INFO - Workflow initialization completed successfully.

# %% [markdown]
# ### 1. Requirements & Planning

# %%
workflow.import_metadata(stage_name="SF_1_Requirements")
JSON(workflow.metadata.to_json())
# Out:
# 2026-06-25 12:24:16 - SurrogateFactoryLogs - INFO - Importing metadata for stage: 'SF_1_Requirements'
# 2026-06-25 12:24:16 - SurrogateFactoryLogs - INFO - Updating metadata for stage 'Requirements' in memory.
# VBox(children=(HTML(value='<h1>Form</h1>'), VBox(children=(Textarea(value='', description='Accuracy', layout=L…

# %% [markdown]
# ### 2. Save

# %%
workflow.save_metadata()
# Out:
# 2026-06-25 12:24:16 - SurrogateFactoryLogs - INFO - Successfully saved workflow metadata to: /Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/data/artifacts/metadata_UCFATIGUE_1.json

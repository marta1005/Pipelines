# %% [markdown]
# # Surrogate Factory — UCFatigue
# ## Chapter 6. Model Selection
# Objectives:
# - Define one MLPRegressor per fatigue output.
# - Review architecture and hyperparameters.

# %% [markdown]
# ### 0. Workflow initialisation

# %%
from IPython.display import display, HTML, JSON
from surrogate_factory.workflow import Workflow

workflow = Workflow("pipeline_config.yaml")
workflow.resume()
# Out:
# 2026-06-25 12:24:29 - SurrogateFactoryLogs - INFO - Initializing Workflow...
# 2026-06-25 12:24:29 - SurrogateFactoryLogs - INFO - Setting up Workflow folders and paths...
# 2026-06-25 12:24:29 - SurrogateFactoryLogs - INFO - Changing working directory to Data folder: /Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/data
# 2026-06-25 12:24:29 - SurrogateFactoryLogs - INFO - Loading default metadata schema...
# 2026-06-25 12:24:29 - SurrogateFactoryLogs - INFO - Tracker requested: 'mlflow'
# 2026-06-25 12:24:30 - SurrogateFactoryLogs - INFO - Setting up MLflow tracking environment...
# Setting tracking uri: file:///Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/mlruns
# 2026-06-25 12:24:30 - SurrogateFactoryLogs - INFO - Adding methods to Catalog from configuration.
# 2026-06-25 12:24:30 - SurrogateFactoryLogs - INFO - Workflow initialization completed successfully.
# 2026-06-25 12:24:30 - SurrogateFactoryLogs - INFO - Resuming workflow job: 'UCFATIGUE_1'
# 2026-06-25 12:24:30 - SurrogateFactoryLogs - INFO - Workflow data loaded successfully.
# 2026-06-25 12:24:30 - SurrogateFactoryLogs - INFO - Workflow metadata successfully loaded for resume.

# %% [markdown]
# ### 6. Model Selection

# %%
workflow.import_metadata(stage_name="SF_6_Model_Selection")
JSON(workflow.metadata.to_json())
# Out:
# 2026-06-25 12:24:30 - SurrogateFactoryLogs - INFO - Importing metadata for stage: 'SF_6_Model_Selection'
# 2026-06-25 12:24:30 - SurrogateFactoryLogs - INFO - Updating metadata for stage 'Model_Selection' in memory.
# VBox(children=(HTML(value='<h1>Form</h1>'), VBox(children=(Textarea(value='', description='Inputs', layout=Lay…

# %% [markdown]
# ### Save

# %%
workflow.save_metadata()
# Out:
# 2026-06-25 12:24:30 - SurrogateFactoryLogs - INFO - Successfully saved workflow metadata to: /Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/data/artifacts/metadata_UCFATIGUE_1.json

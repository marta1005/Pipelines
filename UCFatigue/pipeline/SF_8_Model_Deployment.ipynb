# %% [markdown]
# # Surrogate Factory — UCFatigue
# ## Chapter 8. Model Deployment
# Objectives:
# - Convert the 7 trained sklearn models to ONNX format.
# - Merge them into a single `model_wrapper.onnx` inference file.

# %% [markdown]
# ### 0. Workflow initialisation

# %%
from IPython.display import display, HTML, JSON
from surrogate_factory.workflow import Workflow

workflow = Workflow("pipeline_config.yaml")
workflow.resume()
# Out:
# 2026-06-25 12:24:40 - SurrogateFactoryLogs - INFO - Initializing Workflow...
# 2026-06-25 12:24:40 - SurrogateFactoryLogs - INFO - Setting up Workflow folders and paths...
# 2026-06-25 12:24:40 - SurrogateFactoryLogs - INFO - Changing working directory to Data folder: /Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/data
# 2026-06-25 12:24:40 - SurrogateFactoryLogs - INFO - Loading default metadata schema...
# 2026-06-25 12:24:40 - SurrogateFactoryLogs - INFO - Tracker requested: 'mlflow'
# 2026-06-25 12:24:40 - SurrogateFactoryLogs - INFO - Setting up MLflow tracking environment...
# Setting tracking uri: file:///Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/mlruns
# 2026-06-25 12:24:40 - SurrogateFactoryLogs - INFO - Adding methods to Catalog from configuration.
# 2026-06-25 12:24:41 - SurrogateFactoryLogs - INFO - Workflow initialization completed successfully.
# 2026-06-25 12:24:41 - SurrogateFactoryLogs - INFO - Resuming workflow job: 'UCFATIGUE_1'
# 2026-06-25 12:24:41 - SurrogateFactoryLogs - INFO - Workflow data loaded successfully.
# 2026-06-25 12:24:41 - SurrogateFactoryLogs - INFO - Workflow metadata successfully loaded for resume.

# %% [markdown]
# ### 8. Model Deployment

# %%
workflow.import_metadata(stage_name="SF_8_Model_Deployment")
# Out:
# 2026-06-25 12:24:41 - SurrogateFactoryLogs - INFO - Importing metadata for stage: 'SF_8_Model_Deployment'
# 2026-06-25 12:24:41 - SurrogateFactoryLogs - INFO - Updating metadata for stage 'Model_Deployment' in memory.
# VBox(children=(HTML(value='<h1>Form</h1>'), VBox(children=(Text(value='', description='Method', layout=Layout(…

# %%
from model_deployment.model import model_deployment
model_deployment(workflow)
# Out:
# 2026-06-25 12:24:41 - SurrogateFactoryLogs - INFO - ▶ Executing Workflow Step: 'model_deployment'
# Saved sklearn pipeline (MLP) → pipeline_UCFATIGUE_1_MLP.pkl
# Saved sklearn pipeline (GradientBoosting) → pipeline_UCFATIGUE_1_GradientBoosting.pkl

# %% [markdown]
# ### Save

# %%
workflow.save_metadata()
# Out:
# 2026-06-25 12:24:41 - SurrogateFactoryLogs - INFO - Successfully saved workflow metadata to: /Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/data/artifacts/metadata_UCFATIGUE_1.json

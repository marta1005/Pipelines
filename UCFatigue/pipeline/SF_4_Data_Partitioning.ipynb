# %% [markdown]
# # Surrogate Factory — UCFatigue
# ## Chapter 4. Data Partitioning
# Objectives:
# - Split the cleaned dataset into Train (80%), Test (10%), Validation (10%) sets.

# %% [markdown]
# ### 0. Workflow initialisation

# %%
from IPython.display import display, HTML, JSON
from surrogate_factory.workflow import Workflow

workflow = Workflow("pipeline_config.yaml")
workflow.resume()
# Out:
# 2026-06-25 12:24:24 - SurrogateFactoryLogs - INFO - Initializing Workflow...
# 2026-06-25 12:24:24 - SurrogateFactoryLogs - INFO - Setting up Workflow folders and paths...
# 2026-06-25 12:24:24 - SurrogateFactoryLogs - INFO - Changing working directory to Data folder: /Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/data
# 2026-06-25 12:24:24 - SurrogateFactoryLogs - INFO - Loading default metadata schema...
# 2026-06-25 12:24:24 - SurrogateFactoryLogs - INFO - Tracker requested: 'mlflow'
# 2026-06-25 12:24:24 - SurrogateFactoryLogs - INFO - Setting up MLflow tracking environment...
# Setting tracking uri: file:///Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/mlruns
# 2026-06-25 12:24:24 - SurrogateFactoryLogs - INFO - Adding methods to Catalog from configuration.
# 2026-06-25 12:24:25 - SurrogateFactoryLogs - INFO - Workflow initialization completed successfully.
# 2026-06-25 12:24:25 - SurrogateFactoryLogs - INFO - Resuming workflow job: 'UCFATIGUE_1'
# 2026-06-25 12:24:25 - SurrogateFactoryLogs - INFO - Workflow data loaded successfully.
# 2026-06-25 12:24:25 - SurrogateFactoryLogs - INFO - Workflow metadata successfully loaded for resume.

# %% [markdown]
# ### 4. Data Partition

# %%
workflow.import_metadata(stage_name="SF_4_Data_Partitioning")
# Out:
# 2026-06-25 12:24:25 - SurrogateFactoryLogs - INFO - Importing metadata for stage: 'SF_4_Data_Partitioning'
# 2026-06-25 12:24:25 - SurrogateFactoryLogs - INFO - Updating metadata for stage 'Data_Partitioning' in memory.
# VBox(children=(HTML(value='<h1>Form</h1>'), VBox(children=(Accordion(children=(VBox(children=(Accordion(childr…

# %%
outputFilename = workflow.config['job_name'] + '_Dataset_cleaned.csv'
Dataset = workflow.load_data(outputFilename)
# Out:
# 2026-06-25 12:24:25 - SurrogateFactoryLogs - INFO - Loading data from '/Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/data/UCFATIGUE_1_Dataset_cleaned.csv' (Format: csv)
# 2026-06-25 12:24:25 - SurrogateFactoryLogs - INFO - Successfully loaded data shape: (869, 29)

# %%
from data_partition.partition import data_split
Train_set, Test_set, Val_set = data_split(workflow, Dataset)
# Out:
# 2026-06-25 12:24:25 - SurrogateFactoryLogs - INFO - ▶ Executing Workflow Step: 'data_split'
# Train: 703 | Test: 79 | Val: 87

# %% [markdown]
# ### Save

# %%
workflow.save_data(Train_set, workflow.config['job_name'] + '_Train_set.csv')
workflow.save_data(Test_set,  workflow.config['job_name'] + '_Test_set.csv')
workflow.save_data(Val_set,   workflow.config['job_name'] + '_Val_set.csv')
workflow.save_metadata()
# Out:
# 2026-06-25 12:24:25 - SurrogateFactoryLogs - INFO - File '/Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/data/UCFATIGUE_1_Train_set.csv' already exists — skipping save (delete data/ folder to rerun from scratch)
# 2026-06-25 12:24:25 - SurrogateFactoryLogs - INFO - File '/Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/data/UCFATIGUE_1_Test_set.csv' already exists — skipping save (delete data/ folder to rerun from scratch)
# 2026-06-25 12:24:25 - SurrogateFactoryLogs - INFO - File '/Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/data/UCFATIGUE_1_Val_set.csv' already exists — skipping save (delete data/ folder to rerun from scratch)
# 2026-06-25 12:24:25 - SurrogateFactoryLogs - INFO - Successfully saved workflow metadata to: /Users/martaarnabatmartin/Desktop/Pipelines/UCFatigue/pipeline/data/artifacts/metadata_UCFATIGUE_1.json

# %% [markdown]
# # Surrogate Factory — UCCpHTP
# ## Chapter 4. Data Partitioning
# Objectives:
# - Data is already split — this stage confirms the split sizes.

# %% [markdown]
# ### 0. Workflow initialisation

# %%
from IPython.display import display, HTML, JSON
from surrogate_factory.workflow import Workflow

workflow = Workflow("pipeline_config.yaml")
workflow.resume()

# %% [markdown]
# ### 4. Data Partition — pre-split, no splitting needed

# %%
workflow.import_metadata(stage_name="SF_4_Data_Partitioning")

# %%
job = workflow.config['job_name']
Train_set = workflow.load_data(job + '_Train_set.csv')
Val_set   = workflow.load_data(job + '_Val_set.csv')
Test_set  = workflow.load_data(job + '_Test_set.csv')

total = len(Train_set) + len(Val_set) + len(Test_set)
print(f'Train : {len(Train_set):>8,} rows  ({100*len(Train_set)/total:.1f} %)')
print(f'Val   : {len(Val_set):>8,} rows  ({100*len(Val_set)/total:.1f} %)')
print(f'Test  : {len(Test_set):>8,} rows  ({100*len(Test_set)/total:.1f} %)')
print(f'Total : {total:>8,} rows')

# %%
workflow.save_metadata()

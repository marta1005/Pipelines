# %% [markdown]
# # Surrogate Factory — UCAirfoils
# ## Chapter 4. Data Partitioning
# Objectives:
# - Split the cleaned dataset into Train (70%), Validation (10%), Test (20%) sets.

# %% [markdown]
# ### 0. Workflow initialisation

# %%
from IPython.display import display, HTML, JSON
from surrogate_factory.workflow import Workflow

workflow = Workflow("pipeline_config.yaml")
workflow.resume()

# %% [markdown]
# ### 4. Data Partition

# %%
workflow.import_metadata(stage_name="SF_4_Data_Partitioning")

# %%
Dataset = workflow.load_data(workflow.config['job_name'] + '_Cleaned.csv')

# %%
from sklearn.model_selection import train_test_split

Train_set, Test_set = train_test_split(Dataset, test_size=0.2, random_state=42)
Train_set, Val_set  = train_test_split(Train_set, test_size=0.125, random_state=42)

print(f'Train : {Train_set.shape[0]} rows')
print(f'Val   : {Val_set.shape[0]} rows')
print(f'Test  : {Test_set.shape[0]} rows')

# %% [markdown]
# ### Save

# %%
job = workflow.config['job_name']
workflow.save_data(Train_set, job + '_Train_set.csv')
workflow.save_data(Val_set,   job + '_Val_set.csv')
workflow.save_data(Test_set,  job + '_Test_set.csv')
workflow.save_metadata()

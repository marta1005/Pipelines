# %% [markdown]
# # Surrogate Factory — UCLoads
# ## Chapter 6. Model Selection
# Objectives:
# - Define model architectures for comparison:
#   - **MLP**: 3 → 64 → 32 → 8 (relu, adam, α=0.01)
#   - **GradientBoosting**: one GBR per output, wrapped in `MultiOutputRegressor`
# - Both models predict all 8 structural load outputs simultaneously.

# %% [markdown]
# ### 0. Workflow initialisation

# %%
from IPython.display import display, HTML, JSON
from surrogate_factory.workflow import Workflow

workflow = Workflow("pipeline_config.yaml")
workflow.resume()

# %% [markdown]
# ### 6. Model Selection

# %%
workflow.import_metadata(stage_name="SF_6_Model_Selection")
JSON(workflow.metadata.to_json())

# %% [markdown]
# ### Save

# %%
workflow.save_metadata()

# %% [markdown]
# # Surrogate Factory — UCLoads
# ## Chapter 4. Data Partitioning
# Objectives:
# - Split the cleaned dataset into **Train / Val / Test** sets.
# - Split ratios: **70 % train / 10 % val / 20 % test** (SF standard, `random_state=42`).
# - Save the three CSV files for downstream stages.

# %% [markdown]
# ### 0. Workflow initialisation

# %%
from IPython.display import display, HTML, JSON
from surrogate_factory.workflow import Workflow

workflow = Workflow("pipeline_config.yaml")
workflow.resume()

# %% [markdown]
# ### 4. Data Partitioning

# %%
workflow.import_metadata(stage_name="SF_4_Data_Partitioning")

# %%
Dataset = workflow.load_data(workflow.config['job_name'] + '_clean_dataset.csv')
print(f"Clean dataset: {Dataset.shape}")

# %%
from data_partition.partition import data_split
Train_set, Test_set, Val_set = data_split(workflow, Dataset)

# %% [markdown]
# ### Save

# %%
job = workflow.config['job_name']
workflow.save_data(Train_set, job + '_Train_set.csv')
workflow.save_data(Test_set,  job + '_Test_set.csv')
workflow.save_data(Val_set,   job + '_Val_set.csv')
workflow.save_metadata()

# %% [markdown]
# # Surrogate Factory — UCLoads
# ## Chapter 3. Data Cleansing
# Objectives:
# - Drop rows with missing values (NaN).
# - Report basic statistics on the cleaned dataset.
# - All columns are numerical — no categorical handling required.

# %% [markdown]
# ### 0. Workflow initialisation

# %%
from IPython.display import display, HTML, JSON
from surrogate_factory.workflow import Workflow

workflow = Workflow("pipeline_config.yaml")
workflow.resume()

# %% [markdown]
# ### 3. Data Cleansing

# %%
workflow.import_metadata(stage_name="SF_3_Data_Cleansing")

# %% [markdown]
# #### 3.1 Load raw dataset

# %%
Dataset = workflow.load_data(workflow.config['job_name'] + '_raw_dataset.csv')
print(f"Raw dataset: {Dataset.shape}")
print(f"Missing values per column:\n{Dataset.isnull().sum()[Dataset.isnull().sum() > 0]}")

# %% [markdown]
# #### 3.2 Drop missing values

# %%
from data_cleansing.clean import drop_missing
Dataset_clean = drop_missing(workflow, Dataset)

# %% [markdown]
# #### 3.3 Statistics

# %%
from data_cleansing.clean import report_statistics
Dataset_final = report_statistics(workflow, Dataset_clean)
Dataset_final.describe()

# %% [markdown]
# ### Save

# %%
outputFilename = workflow.config['job_name'] + '_clean_dataset.csv'
workflow.save_data(Dataset_final, outputFilename)
workflow.save_metadata()

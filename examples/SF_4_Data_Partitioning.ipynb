# %% [markdown]
# # Surrogate Factory Notebook template
# ## Chapter 4. Data Partitioning
# Objective of this template:
# - Split data for crossvalidation

# %% [markdown]
# ### 0.- Define general config of the workflow
#
# Surrogate Factory Initialisation

# %%
from IPython.display import display, HTML, JSON
from surrogate_factory.workflow import Workflow

workflow = Workflow("pipeline_config.yaml")
workflow.resume()
# Out:
# Setting up Workflow folders
# Change to Data folder /home/c05279/Pipelines/Training/working_pipeline/data
# tracker requested mlflow
# Setting tracking uri: http://127.0.0.1:55000
# 2026-02-04 10:42:41.083229: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-04 10:42:41.092941: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770198161.102633 1943667 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770198161.105548 1943667 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770198161.114354 1943667 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770198161.114365 1943667 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770198161.114366 1943667 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770198161.114367 1943667 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-04 10:42:41.117586: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Adding methods to Catalog
# Workflow data loaded successfully.
# /home/FlightPhysicsValidation/sFactoryTraining/lib/python3.10/site-packages/surrogate_factory/metadata.py:488: UserWarning: Loading data without validation as no schema was provided.
#   warnings.warn("Loading data without validation as no schema was provided.")

# %%
JSON(workflow.metadata.to_json())

# %% [markdown]
# ### 5.- Data Partitioning
#
# Here, data will be splitted in the datasets required. By default, it must consider Train set and Test Set, but some more could be required for Hypertuning and Validation.
# Refers to https://confluence.airbus.corp/display/I2G22DIHI/4.+Data+Partitioning for more details.
#
# Regarding Metadata, this must be provided in the chapter Partition:
# * Algorithm used
# * Percentage for training, validation and test set
# * Input file
# * Output files

# %%
workflow.import_metadata(stage_name="SF_4_Data_Partitioning")
# Out:
# Updating metadata for  Data_Partitioning
# building_schema {'type': 'object', 'properties': {'Data_Partition': {'type': 'object', 'properties': {'algorithm': {'type': 'string'}, 'percentages': {'type': 'object', 'properties': {'train': {'type': 'number'}, 'test': {'type': 'number'}, 'validation': {'type': 'number'}}}}}}, '$schema': 'http://json-schema.org/draft-07/schema#', 'title': 'Data_Partitioning'}
# VBox(children=(HTML(value='<h1>Data Partitioning</h1>'), VBox(children=(Accordion(children=(VBox(children=(Tex…

# %%
outputFilename = workflow.config['job_name'] + '_Dataset_cleaned.csv'
Dataset = workflow.load_data(outputFilename)
Dataset
# Out:
#            Pin_D  R_DextDint   Male_Dt  Male_RoD  angle_env_reduc0  \
# 0      27.224426    1.913879  5.478052  1.885291        178.582764
# 1      15.322571    1.879211  4.826685  1.687732        113.807373
# 2      40.108185    1.874359  2.475867  1.983685         90.082397
# 3      27.281075    1.748955  7.848734  1.677788         35.992584
# 4      63.276463    1.643589  4.984297  1.472298        176.147232
# ...          ...         ...       ...       ...               ...
# 90084  43.170052    1.116081  9.239627  1.542693        178.034821
# 90085  64.803391    1.356918  5.763727  1.225986         16.575623
# 90086  27.910500    1.668053  9.830630  2.133531         43.963165
# 90087  31.667023    1.544525  9.490417  1.800824          2.587280
# 90088  54.257088    1.466301  7.363016  0.988127        109.062653
#
#        angle_env_reduc1  Female_RoD  Female_Dt   pin_doD TypeLC        gap  \
# 0            113.170166    0.834949   2.553638  0.402100  UL/LL  11.398499
# 1             11.656494    1.255359   5.262427  0.408740  UL/LL   6.542542
# 2            154.725952    1.547809   4.331702  0.728247  UL/LL   8.051300
# 3            164.700165    1.027925   5.667355  0.700800  UL/LL   2.535484
# 4             97.454910    1.950803   8.037651  0.171457     UL  12.121090
# ...                 ...         ...        ...       ...    ...        ...
# 90084         62.626190    1.824739   6.337253  0.134442     UL   4.521507
# 90085          4.023743    1.077560   8.718744  0.309265     UL  12.957047
# 90086         12.028656    1.757961   5.716489  0.438129     UL  14.665459
# 90087        149.320679    1.534479   9.091174  0.755396  UL/LL   5.883575
# 90088        136.212616    2.095271   1.030856  0.215594  UL/LL  13.879539
#
#         mat   RF_Lug1   RF_Lug2    RF_Pin
# 0      MAT1  0.822762  2.115400  0.441427
# 1      MAT1  0.290441  0.182754  0.160779
# 2      MAT1  3.869550  1.416690  0.844316
# 3      MAT1  0.509013  0.325061  0.432439
# 4      MAT1  3.228160  2.272100  5.026540
# ...     ...       ...       ...       ...
# 90084  MAT3  0.123294  0.411136  1.914910
# 90085  MAT3  0.521953  0.356035  3.923750
# 90086  MAT3  0.146325  0.219746  0.386970
# 90087  MAT3  0.145930  0.144822  0.378877
# 90088  MAT3  0.229571  4.113610  1.320460
#
# [90089 rows x 15 columns]

# %%
from data_partition.partition import data_split
Train_set,Test_set,Val_set = data_split(
                                              workflow,
                                              Dataset
                                              )
# Out:
# Setting current step ['metadata', 'Data_Partition']
# 0.8 0.2 0.2

# %% [markdown]
# ### Save Data

# %%
outputFilename = workflow.config['job_name'] + '_Train_set.csv'

workflow.save_data(Train_set,  outputFilename)
# Out:
# File /home/c05279/Pipelines/Training/working_pipeline/data/TRAINING_1_Train_set.csv already exists

# %%
outputFilename = workflow.config['job_name'] + '_Test_set.csv'

workflow.save_data(Test_set,  outputFilename)
# Out:
# File /home/c05279/Pipelines/Training/working_pipeline/data/TRAINING_1_Test_set.csv already exists

# %%
outputFilename = workflow.config['job_name'] + '_Val_set.csv'

workflow.save_data(Val_set,  outputFilename)
# Out:
# File /home/c05279/Pipelines/Training/working_pipeline/data/TRAINING_1_Val_set.csv already exists

# %%
workflow.save_metadata()
# Out:
# Saved Metadata: metadata_TRAINING_1.json

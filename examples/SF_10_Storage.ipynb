# %% [markdown]
# # Surrogate Factory Notebook template
# ## Chapter 10. Storage
# Objectives of this template:
# - Wrap the model for model deployment
# - Perform functional test of the model wrapped vs model trained
# - Store the model

# %% [markdown]
#  **Copyright (c) 2025 Airbus Operations S. L.
#  This file is part of project Surrogate Factory released under the Airbus Inner Source shared-maintenance**

# %% [markdown]
# ### 0.- Define general config of the workflow

# %%
from IPython.display import display, HTML, JSON
from surrogate_factory.workflow import Workflow

workflow = Workflow("pipeline_config.yaml")
workflow.resume()
# Out:
# Setting up Workflow folders
# Change to Data folder /home/c05279/Pipelines/Training/working_pipeline/data
# tracker requested mlflow
# Setting tracking uri: http://127.0.0.1:55000
# 2026-02-04 10:59:17.363228: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-04 10:59:17.372299: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770199157.381365 1946581 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %% [markdown]
# ### 9 Storage

# %% [markdown]
# If validation passed, model artifacts and data will be now stored in the persistance volume (Artifactory)

# %% [markdown]
# #### 9.1 Pipeline Archiving

# %% [markdown]
# - [ ] Store pipeline and all dependencies

# %% [markdown]
# #### 9.2 Model Distribution
# Store models and metadata

# %%
## UPLOAD MODEL TO ARTIFACTORY
from storage.model import upload_model
hashcode = upload_model(workflow)
# Out:
# Setting current step []
# /home/FlightPhysicsValidation/sFactoryTraining/lib/python3.10/site-packages/surrogate_factory/metadata.py:80: UserWarning: upload_model is not in the process mapping. It must be one of these: ['define_doe', 'launch_sim', 'batch_extract', 'batch_transform', 'batch_load', 'replace_missing_values', 'filter_outliers', 'data_split', 'explore_data_analysis', 'add_features', 'preprocessor', 'postprocessor', 'define_model', 'train', 'model_deployment', 'calculate_metrics', 'validate']
#   warnings.warn(

# %% [markdown]
# #### 9.2 Model integration test

# %% [markdown]
# Execute a functional test of the model stored to ensure it is stored correctly

# %% [markdown]
# from storage.integration import model_test
# model_test(workflow, hashcode)
